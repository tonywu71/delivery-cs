# %% [markdown]
# ### Imports

# %%
import pandas as pd
import utils as ut

# %% [markdown]
# ### Load data

# %%
daily_df = ut.load_df("daily_weather_data_from_2009_to_present.pkl")
hourly_df = ut.load_df("hourly_weather_data_from_2009_to_present.pkl")
combined_df = ut.load_df("combined_weather_data_from_2009_to_present.pkl")
# print(daily_df.columns)
# print(hourly_df.columns)
print(combined_df.columns)
# Out:
# Index(['tempC', 'windspeedKmph', 'winddirDegree', 'weatherCode', 'precipMM',
#        'humidity', 'visibility', 'pressure', 'cloudcover', 'HeatIndexC',
#        'DewPointC', 'WindChillC', 'WindGustKmph', 'FeelsLikeC',
#        'hourly_uvIndex', 'datetime', 'maxtempC', 'mintempC', 'avgtempC',
#        'totalSnow_cm', 'sunHour', 'daily_uvIndex', 'sunrise', 'sunset',
#        'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
print(daily_df.columns)
daily_df.plot(x="date", y=["avgtempC"]);
daily_df.plot(x="date", y=["uvIndex"]);
# Out:
# Index(['date', 'maxtempC', 'mintempC', 'avgtempC', 'totalSnow_cm', 'sunHour',
#        'uvIndex', 'sunrise', 'sunset', 'moon_phase', 'moon_illumination'],
#       dtype='object')
