# %%
import pandas as pd

from planning_livreurs import *

from IPython.display import HTML
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
list_streets = ['Champs-Elysées', 'Convention', 'Sts']

# %%
# On crée le dictionnaire avec des VBox vide :
dic_widgets_streets = {key: widgets.VBox() for key in list_streets}
dic_widgets_streets
# Out:
# {'Champs-Elysées': VBox(), 'Convention': VBox(), 'Sts': VBox()}

# %%
for key in dic_widgets_streets.keys():
    # On associera le 1er élément de VBox.children comme étant relatif aux vendeurs
    # et le 2nd élément sera lié aux colis.
    dic_widgets_streets[key].children = [
        widgets.HTML(value=f'<b>{key} :</b>'),
        widgets.IntSlider(value=7,
                          min=0,
                          max=10,
                          step=1,
                          description='#vendeurs:'),
        widgets.IntSlider(value=7,
                          min=0,
                          max=10,
                          step=1,
                          description='#colis:')
    ]

# %%
hbox_children = list(dic_widgets_streets.values())
hbox = widgets.HBox(hbox_children)
hbox
# Out:
# HBox(children=(VBox(children=(HTML(value='<b>Champs-Elysées :</b>'), IntSlider(value=7, description='#vendeurs…

# %%
hbox.children = [ dic_widgets['sts']['colis']]

# %%
hbox
# Out:
# HBox(children=(IntSlider(value=7, description='#colis:', max=10),))

# %%
update_button = widgets.Button(
    description='Mettre à jour',
)

container = widgets.VBox([hbox ,update_button])

@update_button.on_click
def update(b=None):
    # Récupération des valeurs des widgets :
    CE_livreurs=dic_widgets_streets['Champs-Elysées'].children[1]
    CE_colis=dic_widgets_streets['Champs-Elysées'].children[2]
    
    Conv_livreurs=dic_widgets_streets['Convention'].children[1]
    Conv_colis=dic_widgets_streets['Convention'].children[2]
    
    Sts_livreurs=dic_widgets_streets['Sts'].children[1]
    Sts_colis=dic_widgets_streets['Sts'].children[2]
    
    # Mise à jour du spreadsheet Excel :
    
    
    # Lecture et affichage du Excel obtenu :
    df = pd.read_excel('planning_test.xls', skiprows=3)
    
    df = df.fillna('')
    df.to_html('table.html')
    
    display(HTML(filename="table.html"))
    
    return

display(container)
# Out:
# VBox(children=(HBox(children=(VBox(children=(HTML(value='<b>Champs-Elysées :</b>'), IntSlider(value=7, descrip…
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Unnamed: 1</th>
#       <th>Avenue des Champs Elysées</th>
#       <th>Sts-Pères</th>
#       <th>Convention</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td></td>
#       <td>0:00-1:00</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td></td>
#       <td>1:00-2:00</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td></td>
#       <td>2:00-3:00</td>
#       <td></td>
#       <td></td>
#       <td>Matthias</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td></td>
#       <td>3:00-4:00</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td></td>
#       <td>4:00-5:00</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td></td>
#       <td>5:00-6:00</td>
#       <td>Carlos</td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td></td>
#       <td>6:00-7:00</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td></td>
#       <td>7:00-8:00</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <