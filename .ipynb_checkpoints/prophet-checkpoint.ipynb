# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re

from fbprophet import Prophet

# %%
df_train = pd.read_pickle('data/df_concat_train.pkl')
df_test = pd.read_pickle('data/df_concat_test.pkl')

len(df_train), len(df_test)

# %%
df_train.head()

# %%
X_train = df_train[['Date et heure de comptage', "champs-elysees_Débit horaire"]]
X_train = X_train.rename(columns={'Date et heure de comptage': 'ds', "champs-elysees_Débit horaire": 'y'})
X_train.head()
# Out:
#                    ds      y
# 0 2019-11-01 04:00:00  746.0
# 1 2019-11-01 05:00:00  549.0
# 2 2019-11-01 06:00:00  503.0
# 3 2019-11-01 07:00:00  500.0
# 4 2019-11-01 08:00:00  525.0

# %%
m = Prophet()
m.fit(X_train)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
l_changepoints = [
    '3/17/2020',
    '5/11/2020',
    '10/17/2020',
    '10/30/2020',
    '11/28/2020',
    '11/28/2020',
    '12/15/2020'
]

# %%
m = Prophet(changepoints=l_changepoints)
m.add_country_holidays(country_name='FR')

# %%
future = m.make_future_dataframe(periods=240, freq = 'H')
print(future['ds'].values[0],future['ds'].values[-1])
# Out:
# 2020-08-10T00:00:00.000000000 2020-11-30T23:00:00.000000000

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                       ds        yhat  yhat_lower  yhat_upper
# 2707 2020-11-30 19:00:00  548.606239  241.681964  878.997322
# 2708 2020-11-30 20:00:00  494.232461  174.742167  794.985757
# 2709 2020-11-30 21:00:00  383.850789   58.029147  727.062632
# 2710 2020-11-30 22:00:00  258.345592  -52.414026  592.888001
# 2711 2020-11-30 23:00:00  172.294026 -153.385478  487.254062

# %%
fig1 = m.plot(forecast)
plt.plot(data.filled_debit.loc["2020-08-10":"2020-11-30"], color='grey', label='real data')
plt.legend()
plt.show()

# %%
fig2 = m.plot_components(forecast)
