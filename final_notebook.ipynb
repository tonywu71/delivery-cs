# %% [markdown]
# <center> <font size='6' font-weight='bold'> BCG Gamma - Datathlon </font> </center>
# <center> <i> Equipe CS Delivery : Matthias Lesage, Julien Pinède, Soukaina Lidam, Carlos Santos García, Timothé Chaumont et Tony Wu </i> </center>
#
# <img src="ressources/couverture.png" />

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Imports-des-modules" data-toc-modified-id="Imports-des-modules-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Imports des modules</a></span></li><li><span><a href="#Import-des-données" data-toc-modified-id="Import-des-données-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Import des données</a></span><ul class="toc-item"><li><span><a href="#Informations-générales" data-toc-modified-id="Informations-générales-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Informations générales</a></span></li><li><span><a href="#Lecture-des-CSV" data-toc-modified-id="Lecture-des-CSV-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Lecture des CSV</a></span></li><li><span><a href="#Filtrage-par-noeud" data-toc-modified-id="Filtrage-par-noeud-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Filtrage par noeud</a></span></li></ul></li><li><span><a href="#Preprocessing-des-données" data-toc-modified-id="Preprocessing-des-données-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Preprocessing des données</a></span><ul class="toc-item"><li><span><a href="#Conversion-en-datetime" data-toc-modified-id="Conversion-en-datetime-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Conversion en datetime</a></span></li><li><span><a href="#Analyse-et-visualisation-(partie-1)" data-toc-modified-id="Analyse-et-visualisation-(partie-1)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Analyse et visualisation (partie 1)</a></span></li><li><span><a href="#Feature-engineering" data-toc-modified-id="Feature-engineering-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Feature engineering</a></span><ul class="toc-item"><li><span><a href="#Categorical-variables" data-toc-modified-id="Categorical-variables-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Categorical variables</a></span></li><li><span><a href="#Features-liées-aux-timestamp" data-toc-modified-id="Features-liées-aux-timestamp-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Features liées aux timestamp</a></span></li><li><span><a href="#Périodes-de-vacances" data-toc-modified-id="Périodes-de-vacances-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Périodes de vacances</a></span></li><li><span><a href="#Confinement" data-toc-modified-id="Confinement-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Confinement</a></span></li><li><span><a href="#Couvre-feu" data-toc-modified-id="Couvre-feu-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Couvre-feu</a></span></li><li><span><a href="#Jours-fériés" data-toc-modified-id="Jours-fériés-4.3.6"><span class="toc-item-num">4.3.6&nbsp;&nbsp;</span>Jours fériés</a></span></li><li><span><a href="#Vacances-scolaires" data-toc-modified-id="Vacances-scolaires-4.3.7"><span class="toc-item-num">4.3.7&nbsp;&nbsp;</span>Vacances scolaires</a></span></li><li><span><a href="#Temps-avant-les-prochaines-grandes-vacances-scolaires" data-toc-modified-id="Temps-avant-les-prochaines-grandes-vacances-scolaires-4.3.8"><span class="toc-item-num">4.3.8&nbsp;&nbsp;</span>Temps avant les prochaines grandes vacances scolaires</a></span></li><li><span><a href="#Données-météorologiques" data-toc-modified-id="Données-météorologiques-4.3.9"><span class="toc-item-num">4.3.9&nbsp;&nbsp;</span>Données météorologiques</a></span></li><li><span><a href="#Moment-de-la-journée" data-toc-modified-id="Moment-de-la-journée-4.3.10"><span class="toc-item-num">4.3.10&nbsp;&nbsp;</span>Moment de la journée</a></span></li><li><span><a href="#Export" data-toc-modified-id="Export-4.3.11"><span class="toc-item-num">4.3.11&nbsp;&nbsp;</span>Export</a></span></li></ul></li></ul></li><li><span><a href="#Analyse-et-visualisation-(partie-2)" data-toc-modified-id="Analyse-et-visualisation-(partie-2)-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Analyse et visualisation (partie 2)</a></span></li><li><span><a href="#Version-concaténée-du-dataset" data-toc-modified-id="Version-concaténée-du-dataset-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Version concaténée du dataset</a></span><ul class="toc-item"><li><span><a href="#Préliminaires" data-toc-modified-id="Préliminaires-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Préliminaires</a></span></li><li><span><a href="#Nettoyage" data-toc-modified-id="Nettoyage-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Nettoyage</a></span></li><li><span><a href="#Export" data-toc-modified-id="Export-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Export</a></span></li></ul></li><li><span><a href="#Pipeline-de-synthèse" data-toc-modified-id="Pipeline-de-synthèse-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Pipeline de synthèse</a></span></li><li><span><a href="#Génération-du-trainset-qui-servira-à-la-prédiction-finale" data-toc-modified-id="Génération-du-trainset-qui-servira-à-la-prédiction-finale-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Génération du trainset qui servira à la prédiction finale</a></span></li><li><span><a href="#Prédiction-avec-SARIMA" data-toc-modified-id="Prédiction-avec-SARIMA-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Prédiction avec SARIMA</a></span><ul class="toc-item"><li><span><a href="#Présentation-du-modèle-retenu" data-toc-modified-id="Présentation-du-modèle-retenu-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Présentation du modèle retenu</a></span></li><li><span><a href="#Chargement-et-nettoyage-des-données" data-toc-modified-id="Chargement-et-nettoyage-des-données-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Chargement et nettoyage des données</a></span></li><li><span><a href="#Traitement-des-dates" data-toc-modified-id="Traitement-des-dates-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Traitement des dates</a></span></li><li><span><a href="#Quelques-fonctions-utilitaires" data-toc-modified-id="Quelques-fonctions-utilitaires-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Quelques fonctions utilitaires</a></span></li><li><span><a href="#Modèles-retenus" data-toc-modified-id="Modèles-retenus-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Modèles retenus</a></span></li><li><span><a href="#Géneration-des-prédictions" data-toc-modified-id="Géneration-des-prédictions-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>Géneration des prédictions</a></span></li><li><span><a href="#Export-des-prédictions" data-toc-modified-id="Export-des-prédictions-9.7"><span class="toc-item-num">9.7&nbsp;&nbsp;</span>Export des prédictions</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
# [insérer intro de Soukaina]
#
# Les parties 2 à 6 montrent en détail le pre-processing des données. Il est néanmoins possible de commencer la lecture des la [partie 7](http://localhost:8888/notebooks/Other%20Documents/bcg-gamma-project/final_notebook.ipynb#Pipeline-de-synthèse) qui présente la pipeline de synthèse.
#
# **Remarques :**
# - Pour profiter de toutes les fonctionnalités de ce noteboook, utiliser Chrome, Firefox ou Edge
# - Nous vous recommandons aussi d'utiliser l'extension *Table of Contents* pour naviguer plus facilement dans ce notebook
# - Les fichiers ayant servi à choisir et tester nos modèles sont dans `data/data_for_baseline`, à ne pas confondre avec les fichiers présents directement dans `data` qui nous ont servis à faire nos prédictions pour le challenge.
#
# <img src="ressources/table_of_contents.png" />

# %% [markdown]
# # Imports des modules

# %% [markdown]
# Avant de lancer la cellule suivante, il est conseillé de créer un nouvel environnement de la manière suivante :
# ```bash
# conda env create --file conda_env.yml
# ```

# %%
import os
import time
import datetime
import itertools
import warnings

import re

from functools import reduce

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import statsmodels.api as sm
from pylab import rcParams
from statsmodels.tools.sm_exceptions import ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning) # Permet d'éviter l'affichage des Warnings

from sklearn.metrics import mean_squared_error

from tqdm import tqdm

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
from cleaning import *

# %% [markdown]
# Le code qui suit peut être intégralement retrouvé dans le fichier `cleaning.ipynb` qui contient l'ensemble du code ayant permis de générer le module `cleaning.py`. Ce notebook détaille toutes les étapes nécessaires au pré-traitement des données et à l'ajout des features supplémentaires utiles à notre objectif.
#
# À titre d'illustration, ce code est également présenté ci-dessous.

# %% [markdown]
# Les données sont enregistrées dans 3 fichiers CSV différents. Elles portent les noms suivants :
# - `champs-elysees.csv`
# - `convention.csv`
# - `sts.csv`.

# %% [markdown]
# Définissons quelques variables globales pour la suite.

# %%
data_path = './data'

# %%
list_filenames = ['champs-elysees.csv', 'convention.csv', 'sts.csv']

# %% [markdown]
# # Import des données

# %% [markdown]
# ## Informations générales

# %% [markdown]
# **Les données  ont été téléchargées depuis :**
# - https://opendata.paris.fr/explore/dataset/comptages-routiers-permanents/information/?disjunctive.libelle&disjunctive.etat_trafic&disjunctive.libelle_nd_amont&disjunctive.libelle_nd_aval&sort=t_1h
#
# **Lien de la notice d'obtention des features :**
# - https://opendata.paris.fr/api/datasets/1.0/comptages-routiers-permanents/attachments/notice_donnes_trafic_capteurs_permanents_version_20190607_pdf/
#
# **Quelques infos issues du site sur le dataset:**
# >**Données de trafic routier issues des capteurs permanents sur 13 mois glissants en J-1**
# Sur le réseau parisien, la mesure du trafic s’effectue majoritairement par le biais de boucles électromagnétiques implantés dans la chaussée.
# La donnée est produite par la Direction de la Voirie et des déplacements - Service des Déplacements - Poste Central d'Exploitation Lutèce.
# La donnée et les visualisations associées (Tableau, Carte et Dataviz) sont brutes sans aucune interprétation ou analyse. Elles donnent à voir la donnée telle qu'elle est publiée quotidiennement.
# Elles donnent un aperçu du taux d'occupation et du débit sur plus de 3000 tronçons de voies. A elles seules, elles ne permettent pas de caractériser la complexité de la circulation à Paris.
# >
# **Deux types de données sont ainsi élaborés :**
# le taux d’occupation, qui correspond au temps de présence de véhicules sur la boucle en pourcentage d’un intervalle de temps fixe (une heure pour les données fournies). Ainsi, 25% de taux d’occupation sur une heure signifie que des véhicules ont été présents sur la boucle pendant 15 minutes. Le taux fournit une information sur la congestion routière. L’implantation des boucles est pensée de manière à pouvoir déduire, d’une mesure ponctuelle, l’état du trafic sur un arc.
# le débit est le nombre de véhicules ayant passé le point de comptage pendant un intervalle de temps fixe (une heure pour les données fournies).
# L'horodate horaire est effectué en fin de période d'élaboration.
# Par exemple, l’horodate « 2019-01-01 01:00:00 » désigne la période du 1er janvier 2019 à 00h00 au 1er janvier 2019 à 01h00.
# Ainsi, l’observation couplée en un point du taux d’occupation et du débit permet de caractériser le trafic. Cela constitue l’un des fondements de l’ingénierie du trafic, et l’on nomme d’ailleurs cela le « diagramme fondamental ».
# Un débit peut correspondre à deux situations de trafic : fluide ou saturée, d’où la nécessité du taux d’occupation. A titre d’exemple : sur une heure, un débit de 100 véhicules par heure sur un axe habituellement très chargé peut se rencontrer de nuit (trafic fluide) ou bien en heure de pointe (trafic saturé).
# >
# **L’équipement du réseau parisien :**
# Les principaux axes de la Ville de Paris sont équipés de stations de comptage des véhicules et de mesure du taux d’occupation, à des fins à la fois de régulation du trafic et des transports en commun, d’information aux usagers (diffusion sur le site Sytadin), et d’étude.
# Il existe deux types de stations sur le réseau : les stations de mesure du taux d’occupation seul, et des stations à la fois de mesure du taux et de comptage des véhicules.
# Les stations de mesure du taux sont implantées très régulièrement : elles permettent une connaissance fine des conditions de circulation.
# Les stations de débit sont moins nombreuses, et généralement implantées entre les principales intersections. En effet, le débit se conserve généralement sur une section entre deux grands carrefours.

# %% [markdown]
# ## Lecture des CSV

# %% [markdown]
# On regroupera toutes les lignes des 3 CSV dans un même DataFrame. Une colonne filename y a été ajoutée pour facilement avoir l'origine de la ligne à portée de main.
#
# Avant tout, nous allons imputer les NaN avec la méthode du *rolling mean*.

# %%
window = 14 # modifier si besoin la taille de la fenêtre

l_df = [pd.read_csv(
    os.path.join(data_path, filename), 
    sep=';', 
    index_col=0).assign(filename=filename) for filename in list_filenames]

for idx, df in enumerate(l_df):
    df = df.sort_values("Date et heure de comptage")
    df['Débit horaire'] = df['Débit horaire'].interpolate()
    df["Taux d'occupation"] = df["Taux d'occupation"].interpolate()
    
    l_df[idx] = df

# %%
df = pd.concat(l_df, ignore_index=True)

df.sample(5)
# Out:
#                   Libelle  Date et heure de comptage  Débit horaire  \
# 230610          Sts_Peres  2020-08-15T19:00:00+02:00          357.0
# 135997         Convention  2020-07-23T06:00:00+02:00           38.0
# 2519    AV_Champs_Elysees  2020-02-14T03:00:00+01:00          433.0
# 123860         Convention  2020-06-27T02:00:00+02:00          404.0
# 75950          Convention  2020-03-19T06:00:00+01:00           25.0
#
#         Taux d'occupation Etat trafic  Identifiant noeud amont  \
# 230610            2.85500      Fluide                      119
# 135997            1.30611      Fluide                     2966
# 2519              5.62611      Fluide                     2294
# 123860            1.88389      Fluide                     2969
# 75950             0.34556      Fluide                     2975
#
#                  Libelle noeud amont  Identifiant noeud aval  \
# 230610          Sts_Peres-Universite                     120
# ...

# %% [markdown]
# Vérification de la non-présence de NaN :

# %%
df.isna().sum()
# Out:
# Libelle                      0
# Date et heure de comptage    0
# Débit horaire                1
# Taux d'occupation            0
# Etat trafic                  0
# Identifiant noeud amont      0
# Libelle noeud amont          0
# Identifiant noeud aval       0
# Libelle noeud aval           0
# Etat arc                     0
# Date debut dispo data        0
# Date fin dispo data          0
# geo_point_2d                 0
# geo_shape                    0
# filename                     0
# dtype: int64

# %% [markdown]
# ## Filtrage par noeud

# %% [markdown]
# On peut déjà drop les identifiants des noeuds et les données liées à la géométrie car ils ne nous serviront pas pour la suite.
# On supprimera aussi

# %%
df = df.drop(columns=[
    'Identifiant noeud amont', 'Identifiant noeud aval', 'geo_point_2d',
    'geo_shape', 'Date debut dispo data', 'Date fin dispo data'
])

# %%
# Contient pour chaque fichier CSV un 2-tuple de la forme (noeud_amont, noeud_aval)
dic_noeuds = {
    'champs-elysees.csv': ('Av_Champs_Elysees-Washington', 'Av_Champs_Elysees-Berri'),
    'convention.csv': ('Lecourbe-Convention', 'Convention-Blomet'),
    'sts.csv': ('Sts_Peres-Voltaire', 'Sts_Peres-Universite')
}

# %%
list_criteria = []
for key, val in dic_noeuds.items():
    criterion = (df['filename']==key) & (df['Libelle noeud amont']==val[0]) & (df['Libelle noeud aval']==val[1])
    list_criteria.append(criterion)

criterion_noeuds = reduce(lambda x, y: x | y, list_criteria)

print(f'Taille du df avant filtrage: {len(df)}')
df = df[criterion_noeuds]
print(f'Taille du df après filtrage: {len(df)}')
# Out:
# Taille du df avant filtrage: 241768
# Taille du df après filtrage: 29009

# %% [markdown]
# On peut désormais drop les libellés.

# %%
df = df.drop(columns=['Libelle noeud amont', 'Libelle noeud aval'])
df.head()
# Out:
#              Libelle  Date et heure de comptage  Débit horaire  \
# 0  AV_Champs_Elysees  2019-11-01T04:00:00+01:00          746.0
# 1  AV_Champs_Elysees  2019-11-01T05:00:00+01:00          549.0
# 2  AV_Champs_Elysees  2019-11-01T06:00:00+01:00          503.0
# 3  AV_Champs_Elysees  2019-11-01T07:00:00+01:00          500.0
# 4  AV_Champs_Elysees  2019-11-01T08:00:00+01:00          525.0
#
#    Taux d'occupation Etat trafic  Etat arc            filename
# 0           10.98889      Fluide  Invalide  champs-elysees.csv
# 1            7.40722      Fluide  Invalide  champs-elysees.csv
# 2            7.66667      Fluide  Invalide  champs-elysees.csv
# 3            4.75500      Fluide  Invalide  champs-elysees.csv
# 4            5.37389      Fluide  Invalide  champs-elysees.csv

# %%
df['filename'].unique()
# Out:
# array(['champs-elysees.csv', 'convention.csv', 'sts.csv'], dtype=object)

# %% [markdown]
# # Preprocessing des données

# %% [markdown]
# ##  Conversion en datetime

# %%
df.dtypes
# Out:
# Libelle                       object
# Date et heure de comptage     object
# Débit horaire                float64
# Taux d'occupation            float64
# Etat trafic                   object
# Etat arc                      object
# filename                      object
# dtype: object

# %%
df['Date et heure de comptage']
# Out:
# 0         2019-11-01T04:00:00+01:00
# 1         2019-11-01T05:00:00+01:00
# 2         2019-11-01T06:00:00+01:00
# 3         2019-11-01T07:00:00+01:00
# 4         2019-11-01T08:00:00+01:00
#                     ...
# 241748    2020-12-10T20:00:00+01:00
# 241752    2020-12-10T21:00:00+01:00
# 241756    2020-12-10T22:00:00+01:00
# 241762    2020-12-10T23:00:00+01:00
# 241764    2020-12-11T00:00:00+01:00
# Name: Date et heure de comptage, Length: 29009, dtype: object

# %% [markdown]
# ‼️ Il semble y avoir un soucis de timezone pour les capteurs... ‼️
#
# **Hypothèse:** On ca supposer que l'heure UTC est la bonne pour la suite.

# %%
def remove_timezone(row):
    return row.tz_localize(None)

# %%
df['Date et heure de comptage'] = pd.to_datetime(df['Date et heure de comptage'], utc=True)
df['Date et heure de comptage'] = df['Date et heure de comptage'].apply(remove_timezone)
df['Date et heure de comptage']
# Out:
# 0        2019-11-01 03:00:00
# 1        2019-11-01 04:00:00
# 2        2019-11-01 05:00:00
# 3        2019-11-01 06:00:00
# 4        2019-11-01 07:00:00
#                  ...
# 241748   2020-12-10 19:00:00
# 241752   2020-12-10 20:00:00
# 241756   2020-12-10 21:00:00
# 241762   2020-12-10 22:00:00
# 241764   2020-12-10 23:00:00
# Name: Date et heure de comptage, Length: 29009, dtype: datetime64[ns]

# %% [markdown]
# On a pour l'instant l'heure UTC. Nous allons nous replacer à l'heure de Paris pour la suite, pour des questions pratiques.

# %%
df.dtypes
# Out:
# Libelle                              object
# Date et heure de comptage    datetime64[ns]
# Débit horaire                       float64
# Taux d'occupation                   float64
# Etat trafic                          object
# Etat arc                             object
# filename                             object
# dtype: object

# %% [markdown]
# On rajoute 1 heure pour revenir à l'heure de Paris.

# %%
df['Date et heure de comptage'] = df['Date et heure de comptage'] + pd.DateOffset(hours=1)
df['Date et heure de comptage']
# Out:
# 0        2019-11-01 04:00:00
# 1        2019-11-01 05:00:00
# 2        2019-11-01 06:00:00
# 3        2019-11-01 07:00:00
# 4        2019-11-01 08:00:00
#                  ...
# 241748   2020-12-10 20:00:00
# 241752   2020-12-10 21:00:00
# 241756   2020-12-10 22:00:00
# 241762   2020-12-10 23:00:00
# 241764   2020-12-11 00:00:00
# Name: Date et heure de comptage, Length: 29009, dtype: datetime64[ns]

# %%
date_begin = df['Date et heure de comptage'].min().strftime('%d/%m/%Y')
date_end = df['Date et heure de comptage'].max().strftime('%d/%m/%Y')
print(f'Première mesure de comptage prise : {date_begin}')
print(f'Dernière mesure de comptage prise : {date_end}')
# Out:
# Première mesure de comptage prise : 01/11/2019
# Dernière mesure de comptage prise : 11/12/2020

# %% [markdown]
# ## Analyse et visualisation (partie 1)

# %%
df[['Débit horaire', "Taux d'occupation"]].describe()
# Out:
#        Débit horaire  Taux d'occupation
# count   29009.000000       29009.000000
# mean      543.231390           8.290648
# std       369.049997           9.482874
# min         0.000000           0.000000
# 25%       201.000000           1.790560
# 50%       508.000000           4.921110
# 75%       841.000000          11.050560
# max      1610.000000          84.668890

# %%
df[['Débit horaire', "Taux d'occupation"]].plot()
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(y='Débit horaire', data=df)
# Out:
# <AxesSubplot:ylabel='Débit horaire'>

# %%
sns.violinplot(y="Taux d'occupation", data=df)
# Out:
# <AxesSubplot:ylabel="Taux d'occupation">

# %%
sns.displot(df, x="Taux d'occupation")

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# ### Categorical variables

# %% [markdown]
# Ajoutons un *one-hot encoding* pour les variables catégoriques. On n'oubliera cependant pas de passer à un *dummy encoding* avant d'entraîner le modèle pour éviter un problème de dimension. ‼️

# %%
df.dtypes
# Out:
# Libelle                              object
# Date et heure de comptage    datetime64[ns]
# Débit horaire                       float64
# Taux d'occupation                   float64
# Etat trafic                          object
# Etat arc                             object
# filename                             object
# dtype: object

# %% [markdown]
# **Ordinal encoding :**

# %% [markdown]
# Il semble en réalité plus pertinent d'utiliser un *ordinal encoding* pour donner une relation d'ordre à la feature. On se servira pour cela des informations contenues dans la notice.
# <img src="ressources/ordinal_encoding.png" />

# %%
 df['Etat trafic']
# Out:
# 0         Fluide
# 1         Fluide
# 2         Fluide
# 3         Fluide
# 4         Fluide
#            ...
# 241748    Fluide
# 241752    Fluide
# 241756    Fluide
# 241762    Fluide
# 241764    Fluide
# Name: Etat trafic, Length: 29009, dtype: object

# %%
mapper = {'Inconnu': 0, 'Fluide': 1, 'Pré-saturé': 2, 'Saturé': 3, 'Bloqué': 4}
df['Etat trafic'] = df['Etat trafic'].map(mapper)
df.sample(5)
# Out:
#                   Libelle Date et heure de comptage  Débit horaire  \
# 223655          Sts_Peres       2020-06-03 09:00:00          558.0
# 1206    AV_Champs_Elysees       2019-12-21 10:00:00          866.0
# 61716          Convention       2020-02-17 14:00:00          800.0
# 7819    AV_Champs_Elysees       2020-09-23 23:00:00          652.0
# 66438          Convention       2020-02-27 10:00:00          891.0
#
#         Taux d'occupation  Etat trafic  Etat arc            filename
# 223655            7.01556            1  Invalide             sts.csv
# 1206             13.77611            1  Invalide  champs-elysees.csv
# 61716             6.75611            1  Invalide      convention.csv
# 7819              6.53833            1  Invalide  champs-elysees.csv
# 66438            16.78056            2  Invalide      convention.csv

# %% [markdown]
# ### Features liées aux timestamp

# %% [markdown]
# Ajout du jour (sans l'heure) :

# %%
df['Date'] = pd.to_datetime(df["Date et heure de comptage"]).dt.date
df.sample(5)
# Out:
#                   Libelle Date et heure de comptage  Débit horaire  \
# 76475          Convention       2020-03-20 08:00:00          302.0
# 157304         Convention       2020-09-05 14:00:00          586.0
# 7696    AV_Champs_Elysees       2020-09-18 20:00:00         1091.0
# 80308          Convention       2020-03-28 08:00:00          146.0
# 218981          Sts_Peres       2020-04-15 17:00:00          141.0
#
#         Taux d'occupation  Etat trafic  Etat arc            filename  \
# 76475             2.25722            1  Invalide      convention.csv
# 157304           16.43611            2  Invalide      convention.csv
# 7696             14.85889            1  Invalide  champs-elysees.csv
# 80308             1.00723            1  Invalide      convention.csv
# 218981            1.62945            1  Invalide             sts.csv
#
#               Date
# 76475   2020-03-20
# 157304  2020-09-05
# 7696    2020-09-18
# 80308   2020-03-28
# 218981  2020-04-15

# %% [markdown]
# Ajout du jour de la semaine:

# %%
df['Jour de la semaine'] = pd.to_datetime(df["Date et heure de comptage"]).dt.dayofweek
df.sample(5)
# Out:
#                   Libelle Date et heure de comptage  Débit horaire  \
# 105768         Convention       2020-05-20 09:00:00          756.0
# 6598    AV_Champs_Elysees       2020-08-04 02:00:00          362.0
# 90827          Convention       2020-04-19 05:00:00           26.0
# 3620    AV_Champs_Elysees       2020-04-01 00:00:00           23.0
# 133358         Convention       2020-07-17 17:00:00         1085.0
#
#         Taux d'occupation  Etat trafic  Etat arc            filename  \
# 105768            5.72945            1  Invalide      convention.csv
# 6598              4.19056            1  Invalide  champs-elysees.csv
# 90827             0.12778            1  Invalide      convention.csv
# 3620              0.30778            1  Invalide  champs-elysees.csv
# 133358            9.69444            1  Invalide      convention.csv
#
#               Date  Jour de la semaine
# 105768  2020-05-20                   2
# 6598    2020-08-04                   1
# ...

# %% [markdown]
# Reste maintenant à one-hot encoder cette variable.
# ‼️ On pensera à drop un des 7 jours pour éviter des problèmes d'overfitting ‼️

# %%
df = pd.concat([
    df,
    pd.get_dummies(df['Jour de la semaine'],
                   prefix='Jour de la semaine',
                   drop_first=False)
], axis=1).drop(columns=['Jour de la semaine'])

df.head()
# Out:
#              Libelle Date et heure de comptage  Débit horaire  \
# 0  AV_Champs_Elysees       2019-11-01 04:00:00          746.0
# 1  AV_Champs_Elysees       2019-11-01 05:00:00          549.0
# 2  AV_Champs_Elysees       2019-11-01 06:00:00          503.0
# 3  AV_Champs_Elysees       2019-11-01 07:00:00          500.0
# 4  AV_Champs_Elysees       2019-11-01 08:00:00          525.0
#
#    Taux d'occupation  Etat trafic  Etat arc            filename        Date  \
# 0           10.98889            1  Invalide  champs-elysees.csv  2019-11-01
# 1            7.40722            1  Invalide  champs-elysees.csv  2019-11-01
# 2            7.66667            1  Invalide  champs-elysees.csv  2019-11-01
# 3            4.75500            1  Invalide  champs-elysees.csv  2019-11-01
# 4            5.37389            1  Invalide  champs-elysees.csv  2019-11-01
#
#    Jour de la semaine_0  Jour de la semaine_1  Jour de la semaine_2  \
# ...

# %% [markdown]
# ### Périodes de vacances

# %% [markdown]
# ### Confinement

# %% [markdown]
# D'après Wikipedia:
# >L'interdiction de déplacement en France, vulgarisée dans les médias par l'expression « confinement de la population » ou « confinement national », est une mesure sanitaire mise en place pour la première fois du 17 mars à 12 h au 11 mai 2020 (55 jours, soit 1 mois et 25 jours), et une deuxième fois à partir du 30 octobre 2020 au 15 décembre 2020 (soit 1 mois et 18 jours), s'insère dans un ensemble de politiques de restrictions de contacts humains et de déplacements en réponse à la pandémie de Covid-19 en France.

# %% [markdown]
# L'objectif est de donner une valeur qui traduit l'intensité du confinement.
#
# Nous allons donc créer une feature `Etat du confinement` qui traduira l'intensité de ce dernier. Elle prendra les valeurs suivantes :
# - 0 -> période avant le 1er confinement
# - 1 -> pas de confinement mais avec expérience du 1er confinement et mesures d'hygiènes renforcées
# - 2 -> confinement assoupli (réouverture des commerces non-essentiels notamment)
# - 3 -> confinement total.

# %%
confinement_1 = pd.date_range(start='3/17/2020', end='5/11/2020')
confinement_2 = pd.date_range(start='10/30/2020', end='11/28/2020')
confinement_2_assoupli = pd.date_range(start='11/28/2020', end='12/15/2020')

# %%
# create a list of our conditions
conditions = [
    (df["Date et heure de comptage"] < confinement_1[0]), # 0
    (confinement_1[0] <= df["Date et heure de comptage"]) & (df["Date et heure de comptage"] < confinement_1[-1]), # 3
    (confinement_1[-1] <= df["Date et heure de comptage"]) & (df["Date et heure de comptage"] < confinement_2[0]), # 1
    (confinement_2[0] <= df["Date et heure de comptage"]) & (df["Date et heure de comptage"] < confinement_2[-1]), # 3
    (confinement_2_assoupli[0] <= df["Date et heure de comptage"]) & (df["Date et heure de comptage"] < confinement_2_assoupli[-1]), # 2
    (confinement_2_assoupli[-1] <= df["Date et heure de comptage"]) # 1
    ]

# create a list of the values we want to assign for each condition
values = [0, 3, 1, 3, 2, 1]

# create a new column and use np.select to assign values to it using our lists as arguments
df['Etat du confinement'] = np.select(conditions, values)
df.sample(5)
# Out:
#                   Libelle Date et heure de comptage  Débit horaire  \
# 236633          Sts_Peres       2020-10-17 12:00:00          674.0
# 12593          Convention       2019-11-07 06:00:00          133.0
# 99591          Convention       2020-05-07 12:00:00          531.0
# 150945         Convention       2020-08-23 08:00:00          151.0
# 151     AV_Champs_Elysees       2019-11-07 11:00:00         1049.0
#
#         Taux d'occupation  Etat trafic  Etat arc            filename  \
# 236633            8.86500            1  Invalide             sts.csv
# 12593             0.85500            1  Invalide      convention.csv
# 99591             3.77556            1  Invalide      convention.csv
# 150945            0.89667            1  Invalide      convention.csv
# 151              33.52889            3  Invalide  champs-elysees.csv
#
#               Date  Jour de la semaine_0  Jour de la semaine_1  \
# 236633  2020-10-17                     0                     0
# ...

# %%
df['Etat du confinement'].value_counts()
# Out:
# 1    12314
# 0     9780
# 3     6048
# 2      867
# Name: Etat du confinement, dtype: int64

# %% [markdown]
# ### Couvre-feu

# %%
couvre_feu_start = pd.Timestamp('10/17/2020')
couvre_feu_start
# Out:
# Timestamp('2020-10-17 00:00:00')

# %%
df['Couvre-feu'] = (couvre_feu_start <= df['Date'])
df.sample(5)
# Out:
#                   Libelle Date et heure de comptage  Débit horaire  \
# 6747    AV_Champs_Elysees       2020-08-10 07:00:00          659.0
# 231530          Sts_Peres       2020-08-25 08:00:00          460.0
# 32585          Convention       2019-12-18 21:00:00          980.0
# 239564          Sts_Peres       2020-11-17 02:00:00           28.0
# 230428          Sts_Peres       2020-08-13 21:00:00          262.0
#
#         Taux d'occupation  Etat trafic  Etat arc            filename  \
# 6747              7.23222            1  Invalide  champs-elysees.csv
# 231530            3.34500            1  Invalide             sts.csv
# 32585            40.34889            3  Invalide      convention.csv
# 239564            0.47500            1  Invalide             sts.csv
# 230428            3.22722            1  Invalide             sts.csv
#
#               Date  Jour de la semaine_0  Jour de la semaine_1  \
# 6747    2020-08-10                     1                     0
# ...

# %% [markdown]
# ### Jours fériés

# %% [markdown]
# Le CSV a été obtenu via le lien suivant :
# - https://www.data.gouv.fr/en/datasets/jours-feries-en-france/

# %%
df_feries = pd.read_csv('data/jours_feries_metropole.csv')
df_feries.head()
# Out:
#          date  annee       zone   nom_jour_ferie
# 0  2000-01-01   2000  Métropole      1er janvier
# 1  2000-04-24   2000  Métropole  Lundi de Pâques
# 2  2000-05-01   2000  Métropole          1er mai
# 3  2000-05-08   2000  Métropole            8 mai
# 4  2000-06-01   2000  Métropole        Ascension

# %%
# On ne garde que les lignes relatives à 2019 ou 2020
df_feries = df_feries[df_feries['annee'].isin(['2019', '2020'])]
df_feries.sample(5)
# Out:
#            date  annee       zone nom_jour_ferie
# 228  2020-11-01   2020  Métropole      Toussaint
# 227  2020-08-15   2020  Métropole     Assomption
# 219  2019-12-25   2019  Métropole   Jour de Noël
# 230  2020-12-25   2020  Métropole   Jour de Noël
# 215  2019-07-14   2019  Métropole     14 juillet

# %%
def get_date(row):
    return row.date()

df_feries['date'] = pd.to_datetime(df_feries['date']).apply(get_date)
series_feries = df_feries['date']

# %%
df['Jour férié'] = df['Date'].isin(series_feries)
df['Jour férié'].value_counts()
# Out:
# False    28085
# True       924
# Name: Jour férié, dtype: int64

# %%
df.head()
# Out:
#              Libelle Date et heure de comptage  Débit horaire  \
# 0  AV_Champs_Elysees       2019-11-01 04:00:00          746.0
# 1  AV_Champs_Elysees       2019-11-01 05:00:00          549.0
# 2  AV_Champs_Elysees       2019-11-01 06:00:00          503.0
# 3  AV_Champs_Elysees       2019-11-01 07:00:00          500.0
# 4  AV_Champs_Elysees       2019-11-01 08:00:00          525.0
#
#    Taux d'occupation  Etat trafic  Etat arc            filename        Date  \
# 0           10.98889            1  Invalide  champs-elysees.csv  2019-11-01
# 1            7.40722            1  Invalide  champs-elysees.csv  2019-11-01
# 2            7.66667            1  Invalide  champs-elysees.csv  2019-11-01
# 3            4.75500            1  Invalide  champs-elysees.csv  2019-11-01
# 4            5.37389            1  Invalide  champs-elysees.csv  2019-11-01
#
#    Jour de la semaine_0  Jour de la semaine_1  Jour de la semaine_2  \
# ...

# %% [markdown]
# ### Vacances scolaires

# %% [markdown]
# Le CSV a été obtenu via le lien suivant :
# - https://www.data.gouv.fr/en/datasets/le-calendrier-scolaire/

# %%
df_vacances = pd.read_csv('data/fr-en-calendrier-scolaire.csv', sep=';')
df_vacances.head()
# Out:
#              description   population  start_date    end_date  location  \
# 0  Vacances de Printemps          NaN  2019-04-13  2019-04-29  Besançon
# 1         Vacances d'Été  Enseignants  2019-07-06  2019-08-30  Besançon
# 2    Pont de l'Ascension          NaN  2020-05-20  2020-05-25  Besançon
# 3       Vacances de Noël          NaN  2020-12-19  2021-01-04  Besançon
# 4    Pont de l'Ascension          NaN  2021-05-13  2021-05-17  Besançon
#
#     zones annee_scolaire
# 0  Zone A      2018-2019
# 1  Zone A      2018-2019
# 2  Zone A      2019-2020
# 3  Zone A      2020-2021
# 4  Zone A      2020-2021

# %%
df_vacances = df_vacances[df_vacances['location'] == 'Paris']
df_vacances.head()
# Out:
#                   description population  start_date    end_date location  \
# 102            Vacances d'Été     Élèves  2018-07-07  2018-09-03    Paris
# 103  Vacances de la Toussaint        NaN  2018-10-20  2018-11-05    Paris
# 104          Vacances de Noël        NaN  2019-12-21  2020-01-06    Paris
# 105          Vacances d'Hiver        NaN  2020-02-08  2020-02-24    Paris
# 280          Vacances de Noël        NaN  2017-12-23  2018-01-08    Paris
#
#       zones annee_scolaire
# 102  Zone C      2017-2018
# 103  Zone C      2018-2019
# 104  Zone C      2019-2020
# 105  Zone C      2019-2020
# 280  Zone C      2017-2018

# %%
df_vacances = df_vacances[df_vacances['annee_scolaire'].isin(['2019-2020', '2020-2021'])]
df_vacances.head()
# Out:
#                description population  start_date    end_date location  \
# 104       Vacances de Noël        NaN  2019-12-21  2020-01-06    Paris
# 105       Vacances d'Hiver        NaN  2020-02-08  2020-02-24    Paris
# 284         Vacances d'Été        NaN  2020-07-04  2020-09-01    Paris
# 285         Vacances d'Été        NaN  2021-07-05         NaN    Paris
# 474  Vacances de Printemps        NaN  2020-04-04  2020-04-20    Paris
#
#       zones annee_scolaire
# 104  Zone C      2019-2020
# 105  Zone C      2019-2020
# 284  Zone C      2019-2020
# 285  Zone C      2020-2021
# 474  Zone C      2019-2020

# %% [markdown]
# On observe un NaN... Affichons toute le DataFrame comme il n'y a que peu de lignes.

# %%
df_vacances
# Out:
#                   description population  start_date    end_date location  \
# 104          Vacances de Noël        NaN  2019-12-21  2020-01-06    Paris
# 105          Vacances d'Hiver        NaN  2020-02-08  2020-02-24    Paris
# 284            Vacances d'Été        NaN  2020-07-04  2020-09-01    Paris
# 285            Vacances d'Été        NaN  2021-07-05         NaN    Paris
# 474     Vacances de Printemps        NaN  2020-04-04  2020-04-20    Paris
# 475       Pont de l'Ascension        NaN  2020-05-20  2020-05-25    Paris
# 476          Vacances de Noël        NaN  2020-12-19  2021-01-04    Paris
# 660          Vacances d'Hiver        NaN  2021-02-13  2021-03-01    Paris
# 845  Vacances de la Toussaint        NaN  2019-10-19  2019-11-04    Paris
# 846  Vacances de la Toussaint        NaN  2020-10-17  2020-11-02    Paris
# 847     Vacances de Printemps        NaN  2021-04-17  2021-05-03    Paris
# 848       Pont de l'Ascension        NaN  2021-05-13  2021-05-17    Paris
#
# ...

# %% [markdown]
# Le seul NaN ne correpond pas à une date comprise dans notre étude. On peut donc la drop sereinement.

# %%
df_vacances = df_vacances[~ df_vacances['end_date'].isna()]
df_vacances
# Out:
#                   description population  start_date    end_date location  \
# 104          Vacances de Noël        NaN  2019-12-21  2020-01-06    Paris
# 105          Vacances d'Hiver        NaN  2020-02-08  2020-02-24    Paris
# 284            Vacances d'Été        NaN  2020-07-04  2020-09-01    Paris
# 474     Vacances de Printemps        NaN  2020-04-04  2020-04-20    Paris
# 475       Pont de l'Ascension        NaN  2020-05-20  2020-05-25    Paris
# 476          Vacances de Noël        NaN  2020-12-19  2021-01-04    Paris
# 660          Vacances d'Hiver        NaN  2021-02-13  2021-03-01    Paris
# 845  Vacances de la Toussaint        NaN  2019-10-19  2019-11-04    Paris
# 846  Vacances de la Toussaint        NaN  2020-10-17  2020-11-02    Paris
# 847     Vacances de Printemps        NaN  2021-04-17  2021-05-03    Paris
# 848       Pont de l'Ascension        NaN  2021-05-13  2021-05-17    Paris
#
#       zones annee_scolaire
# 104  Zone C      2019-2020
# ...

# %%
df_vacances.dtypes
# Out:
# description       object
# population        object
# start_date        object
# end_date          object
# location          object
# zones             object
# annee_scolaire    object
# dtype: object

# %%
df_vacances['start_date'] = pd.to_datetime(df_vacances['start_date'])
df_vacances['end_date'] = pd.to_datetime(df_vacances['end_date'])

df_vacances.dtypes
# Out:
# /Users/Tony/opt/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/Tony/opt/anaconda3/envs/ML/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# description               object
# population                object
# start_date        datetime64[ns]
# end_date          datetime64[ns]
# location                  object
# ...

# %% [markdown]
# On peut maintenant ajouter notre colonne `Vacances scolaires` à notre DataFrame de départ.

# %%
def est_pendant_vacances(date):    
    for index, row_vacances in df_vacances.iterrows():
        start = row_vacances['start_date']
        end = row_vacances['end_date']
        
        if start < date < end:
            return True
        else:
            pass
    
    return False

df['Vacances scolaires'] = df['Date'].apply(est_pendant_vacances)
df.sample(5)
# Out:
#            Libelle Date et heure de comptage  Débit horaire  \
# 223688   Sts_Peres       2020-06-03 18:00:00          619.0
# 203339   Sts_Peres       2019-11-03 18:00:00          507.0
# 74342   Convention       2020-03-15 21:00:00          499.0
# 52838   Convention       2020-01-30 02:00:00          205.0
# 18222   Convention       2019-11-18 23:00:00          462.0
#
#         Taux d'occupation  Etat trafic  Etat arc        filename        Date  \
# 223688            6.08167            1  Invalide         sts.csv  2020-06-03
# 203339            6.21056            1  Invalide         sts.csv  2019-11-03
# 74342             2.59667            1  Invalide  convention.csv  2020-03-15
# 52838             0.99445            1  Invalide  convention.csv  2020-01-30
# 18222             2.67389            1  Invalide  convention.csv  2019-11-18
#
#         Jour de la semaine_0  Jour de la semaine_1  Jour de la semaine_2  \
# ...

# %% [markdown]
# ### Temps avant les prochaines grandes vacances scolaires

# %% [markdown]
# Déjà, créons un DataFrame avec uniquement les grandes vacances.

# %%
df_grandes_vacances = df_vacances[df_vacances['description'].str.contains('Vacances')]
df_grandes_vacances.head()
# Out:
#                description population start_date   end_date location   zones  \
# 104       Vacances de Noël        NaN 2019-12-21 2020-01-06    Paris  Zone C
# 105       Vacances d'Hiver        NaN 2020-02-08 2020-02-24    Paris  Zone C
# 284         Vacances d'Été        NaN 2020-07-04 2020-09-01    Paris  Zone C
# 474  Vacances de Printemps        NaN 2020-04-04 2020-04-20    Paris  Zone C
# 476       Vacances de Noël        NaN 2020-12-19 2021-01-04    Paris  Zone C
#
#     annee_scolaire
# 104      2019-2020
# 105      2019-2020
# 284      2019-2020
# 474      2019-2020
# 476      2020-2021

# %% [markdown]
# On trie maintenant ce DataFrame par ordre chronologique.

# %%
df_grandes_vacances = df_grandes_vacances.sort_values(by=['start_date'])
df_grandes_vacances.head()
# Out:
#                   description population start_date   end_date location  \
# 845  Vacances de la Toussaint        NaN 2019-10-19 2019-11-04    Paris
# 104          Vacances de Noël        NaN 2019-12-21 2020-01-06    Paris
# 105          Vacances d'Hiver        NaN 2020-02-08 2020-02-24    Paris
# 474     Vacances de Printemps        NaN 2020-04-04 2020-04-20    Paris
# 284            Vacances d'Été        NaN 2020-07-04 2020-09-01    Paris
#
#       zones annee_scolaire
# 845  Zone C      2019-2020
# 104  Zone C      2019-2020
# 105  Zone C      2019-2020
# 474  Zone C      2019-2020
# 284  Zone C      2019-2020

# %%
# create a list of our conditions
conditions = []

# create a list of the values we want to assign for each condition
values = []

for idx, row in df_grandes_vacances.iterrows():
    conditions.append(df["Date et heure de comptage"] < row['start_date'])
    values.append(row['start_date'])

df['Date des prochaines vacances scolaires'] = np.select(conditions, values)
df['Date des prochaines vacances scolaires'] = df['Date des prochaines vacances scolaires']
df.sample(5)
# Out:
#                   Libelle Date et heure de comptage  Débit horaire  \
# 78227          Convention       2020-03-23 23:00:00           97.0
# 6479    AV_Champs_Elysees       2020-07-30 03:00:00          246.0
# 180950         Convention       2020-10-24 21:00:00          411.0
# 162585         Convention       2020-09-16 14:00:00          916.0
# 144186         Convention       2020-08-09 06:00:00          123.0
#
#         Taux d'occupation  Etat trafic  Etat arc            filename  \
# 78227             0.61278            1  Invalide      convention.csv
# 6479              2.89778            1  Invalide  champs-elysees.csv
# 180950            1.78611            1  Invalide      convention.csv
# 162585            6.67278            1  Invalide      convention.csv
# 144186            0.54278            1  Invalide      convention.csv
#
#               Date  Jour de la semaine_0  Jour de la semaine_1  \
# 78227   2020-03-23                     1                     0
# ...

# %%
df['Temps avant les prochaines vacances scolaires'] = df['Date des prochaines vacances scolaires'] - df['Date et heure de comptage']
df.sample(5)
# Out:
#            Libelle Date et heure de comptage  Débit horaire  \
# 105679  Convention       2020-05-20 04:00:00           51.0
# 237242   Sts_Peres       2020-10-23 20:00:00          696.0
# 240273   Sts_Peres       2020-11-24 11:00:00          613.0
# 19092   Convention       2019-11-20 19:00:00          997.0
# 207299   Sts_Peres       2019-12-15 00:00:00          694.0
#
#         Taux d'occupation  Etat trafic  Etat arc        filename        Date  \
# 105679            0.22945            1  Invalide  convention.csv  2020-05-20
# 237242            7.48556            1  Invalide         sts.csv  2020-10-23
# 240273            8.30778            1  Invalide         sts.csv  2020-11-24
# 19092            47.19889            3  Invalide  convention.csv  2019-11-20
# 207299            8.39278            1  Invalide         sts.csv  2019-12-15
#
#         Jour de la semaine_0  Jour de la semaine_1  ...  Jour de la semaine_3  \
# ...

# %% [markdown]
# ### Données météorologiques

# %%
df_weather = pd.read_pickle('data/combined_weather_data_from_2009_to_present.pkl')
df_weather.head()
# Out:
#    tempC  windspeedKmph  winddirDegree  weatherCode  precipMM  humidity  \
# 0     -3              6             51          260       0.0        97
# 1     -3              5             44          260       0.0        97
# 2     -3              4             37          143       0.0        97
# 3     -3              3             30          143       0.0        97
# 4     -3              5             31          143       0.0        96
#
#    visibility  pressure  cloudcover  HeatIndexC  ...  maxtempC  mintempC  \
# 0           0      1028          35          -2  ...         2        -4
# 1           1      1028          32          -2  ...         2        -4
# 2           1      1028          29          -2  ...         2        -4
# 3           2      1028          27          -2  ...         2        -4
# 4           2      1028          24          -2  ...         2        -4
#
#    avgtempC  totalSnow_cm  sunHour daily_uvIndex             sunrise  \
# ...

# %%
df_weather.columns
# Out:
# Index(['tempC', 'windspeedKmph', 'winddirDegree', 'weatherCode', 'precipMM',
#        'humidity', 'visibility', 'pressure', 'cloudcover', 'HeatIndexC',
#        'DewPointC', 'WindChillC', 'WindGustKmph', 'FeelsLikeC',
#        'hourly_uvIndex', 'datetime', 'maxtempC', 'mintempC', 'avgtempC',
#        'totalSnow_cm', 'sunHour', 'daily_uvIndex', 'sunrise', 'sunset',
#        'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
df = df.merge(df_weather, left_on='Date et heure de comptage', right_on='datetime', how='left').drop(columns=['datetime'])
df.head()
# Out:
#              Libelle Date et heure de comptage  Débit horaire  \
# 0  AV_Champs_Elysees       2019-11-01 04:00:00          746.0
# 1  AV_Champs_Elysees       2019-11-01 05:00:00          549.0
# 2  AV_Champs_Elysees       2019-11-01 06:00:00          503.0
# 3  AV_Champs_Elysees       2019-11-01 07:00:00          500.0
# 4  AV_Champs_Elysees       2019-11-01 08:00:00          525.0
#
#    Taux d'occupation  Etat trafic  Etat arc            filename        Date  \
# 0           10.98889            1  Invalide  champs-elysees.csv  2019-11-01
# 1            7.40722            1  Invalide  champs-elysees.csv  2019-11-01
# 2            7.66667            1  Invalide  champs-elysees.csv  2019-11-01
# 3            4.75500            1  Invalide  champs-elysees.csv  2019-11-01
# 4            5.37389            1  Invalide  champs-elysees.csv  2019-11-01
#
#    Jour de la semaine_0  Jour de la semaine_1  ...  maxtempC  mintempC  \
# ...

# %% [markdown]
# Liste des colonnes à disposition :

# %%
df.columns
# Out:
# Index(['Libelle', 'Date et heure de comptage', 'Débit horaire',
#        'Taux d'occupation', 'Etat trafic', 'Etat arc', 'filename', 'Date',
#        'Jour de la semaine_0', 'Jour de la semaine_1', 'Jour de la semaine_2',
#        'Jour de la semaine_3', 'Jour de la semaine_4', 'Jour de la semaine_5',
#        'Jour de la semaine_6', 'Etat du confinement', 'Couvre-feu',
#        'Jour férié', 'Vacances scolaires',
#        'Date des prochaines vacances scolaires',
#        'Temps avant les prochaines vacances scolaires', 'tempC',
#        'windspeedKmph', 'winddirDegree', 'weatherCode', 'precipMM', 'humidity',
#        'visibility', 'pressure', 'cloudcover', 'HeatIndexC', 'DewPointC',
#        'WindChillC', 'WindGustKmph', 'FeelsLikeC', 'hourly_uvIndex',
#        'maxtempC', 'mintempC', 'avgtempC', 'totalSnow_cm', 'sunHour',
#        'daily_uvIndex', 'sunrise', 'sunset', 'moon_phase',
#        'moon_illumination'],
#       dtype='object')

# %% [markdown]
# ### Moment de la journée

# %%
# create a list of our conditions
criterion = (df['sunrise'] <= df["Date et heure de comptage"]) & (df["Date et heure de comptage"] < df['sunset'])

# create a new column and use np.select to assign values to it using our lists as arguments
df['Journée'] = criterion
df.sample(5)
# Out:
#                  Libelle Date et heure de comptage  Débit horaire  \
# 11655         Convention       2020-01-22 23:00:00          618.0
# 9634   AV_Champs_Elysees       2020-12-08 15:00:00         1280.0
# 17569         Convention       2020-09-27 06:00:00          146.0
# 14487         Convention       2020-05-20 23:00:00          388.0
# 19706          Sts_Peres       2019-11-16 11:00:00          636.0
#
#        Taux d'occupation  Etat trafic  Etat arc            filename  \
# 11655            2.92500            1  Invalide      convention.csv
# 9634            22.55778            2  Invalide  champs-elysees.csv
# 17569            0.86389            1  Invalide      convention.csv
# 14487            2.17222            1  Invalide      convention.csv
# 19706            8.42056            1  Invalide             sts.csv
#
#              Date  Jour de la semaine_0  Jour de la semaine_1  ...  mintempC  \
# 11655  2020-01-22                     0                     0  ...         1
# ...

# %% [markdown]
# ### Export

# %% [markdown]
# À ce stade, le dataset a été entièrement nettoyé et est maintenant prêt à être utilisé ! ✅
# Dans la fonction de pipeline finale, on l'exportera sous forme de `pickle` pour conserver les différents formats dont `datetime`.

# %% [markdown]
# # Analyse et visualisation (partie 2)

# %% [markdown]
# Analysons rapidement quelques informations statistiques sur nos nouvelles features.

# %%
df.columns
# Out:
# Index(['Libelle', 'Date et heure de comptage', 'Débit horaire',
#        'Taux d'occupation', 'Etat trafic', 'Etat arc', 'filename', 'Date',
#        'Jour de la semaine_0', 'Jour de la semaine_1', 'Jour de la semaine_2',
#        'Jour de la semaine_3', 'Jour de la semaine_4', 'Jour de la semaine_5',
#        'Jour de la semaine_6', 'Etat du confinement', 'Couvre-feu',
#        'Jour férié', 'Vacances scolaires',
#        'Date des prochaines vacances scolaires',
#        'Temps avant les prochaines vacances scolaires', 'tempC',
#        'windspeedKmph', 'winddirDegree', 'weatherCode', 'precipMM', 'humidity',
#        'visibility', 'pressure', 'cloudcover', 'HeatIndexC', 'DewPointC',
#        'WindChillC', 'WindGustKmph', 'FeelsLikeC', 'hourly_uvIndex',
#        'maxtempC', 'mintempC', 'avgtempC', 'totalSnow_cm', 'sunHour',
#        'daily_uvIndex', 'sunrise', 'sunset', 'moon_phase', 'moon_illumination',
#        'Journée'],
#       dtype='object')

# %%
corr = df.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    plt.figure(figsize=(12,12))
    ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)

# %% [markdown]
# # Version concaténée du dataset

# %% [markdown]
# **Motivation :** Pour les besoins du modèle CNN, nous avons besoin d'un DataFrame avec les valeurs des 3 arcs à chaque ligne (et non pas une ligne par arc).

# %% [markdown]
# ## Préliminaires

# %%
for filename in list_filenames:
    print(f'{filename}')
    date_begin = df['Date et heure de comptage'][df['filename']==filename].min().strftime('%d/%m/%Y')
    date_end = df['Date et heure de comptage'][df['filename']==filename].max().strftime('%d/%m/%Y')
    print(f'Première mesure de comptage prise : {date_begin}')
    print(f'Dernière mesure de comptage prise : {date_end}')
    print(f'len: {len(df[df["filename"]==filename])}')
    print()
# Out:
# champs-elysees.csv
# Première mesure de comptage prise : 01/11/2019
# Dernière mesure de comptage prise : 11/12/2020
# len: 9668
#
# convention.csv
# Première mesure de comptage prise : 01/11/2019
# Dernière mesure de comptage prise : 11/12/2020
# len: 9671
#
# sts.csv
# Première mesure de comptage prise : 01/11/2019
# Dernière mesure de comptage prise : 11/12/2020
# len: 9670

# %% [markdown]
# ## Nettoyage

# %%
list_filenames
# Out:
# ['champs-elysees.csv', 'convention.csv', 'sts.csv']

# %%
l_df = [df[df['filename']==elt] for elt in list_filenames]
l_df[0].head()
# Out:
#              Libelle Date et heure de comptage  Débit horaire  \
# 0  AV_Champs_Elysees       2019-11-01 04:00:00          746.0
# 1  AV_Champs_Elysees       2019-11-01 05:00:00          549.0
# 2  AV_Champs_Elysees       2019-11-01 06:00:00          503.0
# 3  AV_Champs_Elysees       2019-11-01 07:00:00          500.0
# 4  AV_Champs_Elysees       2019-11-01 08:00:00          525.0
#
#    Taux d'occupation  Etat trafic  Etat arc            filename        Date  \
# 0           10.98889            1  Invalide  champs-elysees.csv  2019-11-01
# 1            7.40722            1  Invalide  champs-elysees.csv  2019-11-01
# 2            7.66667            1  Invalide  champs-elysees.csv  2019-11-01
# 3            4.75500            1  Invalide  champs-elysees.csv  2019-11-01
# 4            5.37389            1  Invalide  champs-elysees.csv  2019-11-01
#
#    Jour de la semaine_0  Jour de la semaine_1  ...  mintempC  avgtempC  \
# ...

# %%
l_cols_original = ['Débit horaire', "Taux d'occupation", "Etat trafic", "Etat arc"]

for idx, (cur_df, filename) in enumerate(zip(l_df, list_filenames)): # we skip the first dataframe
    l_cols_new = [filename[:-4] + '_' + elt for elt in l_cols_original]
    
    l_df[idx] = cur_df.rename(columns=dict(zip(l_cols_original, l_cols_new))).drop(columns=['Libelle'])

l_df[0].head()
# Out:
#   Date et heure de comptage  champs-elysees_Débit horaire  \
# 0       2019-11-01 04:00:00                         746.0
# 1       2019-11-01 05:00:00                         549.0
# 2       2019-11-01 06:00:00                         503.0
# 3       2019-11-01 07:00:00                         500.0
# 4       2019-11-01 08:00:00                         525.0
#
#    champs-elysees_Taux d'occupation  champs-elysees_Etat trafic  \
# 0                          10.98889                           1
# 1                           7.40722                           1
# 2                           7.66667                           1
# 3                           4.75500                           1
# 4                           5.37389                           1
#
#   champs-elysees_Etat arc            filename        Date  \
# 0                Invalide  champs-elysees.csv  2019-11-01
# 1                Invalide  champs-elysees.csv  2019-11-01
# ...

# %%
def concat_reduce(df_1, df_2):
    filename = df_2['filename'].iloc[0][:-4]
    l_cols_original = ['Débit horaire', "Taux d'occupation", "Etat trafic", "Etat arc"]
    l_cols = ['Date et heure de comptage'] + [filename + '_' + elt for elt in l_cols_original]
    
    return df_1.merge(df_2[l_cols], on='Date et heure de comptage')

df_concat = reduce(concat_reduce, l_df)
df_concat = df_concat.sort_values(by='Date et heure de comptage')

df_concat.sample(10)
# Out:
#      Date et heure de comptage  champs-elysees_Débit horaire  \
# 1793       2020-01-14 21:00:00                        1057.0
# 1457       2019-12-31 21:00:00                         374.0
# 5964       2020-07-08 16:00:00                        1184.0
# 7305       2020-09-02 13:00:00                        1150.0
# 8116       2020-10-06 08:00:00                        1301.0
# 1636       2020-01-08 08:00:00                        1224.0
# 7474       2020-09-09 14:00:00                        1121.0
# 2688       2020-02-21 04:00:00                         366.0
# 8347       2020-10-15 23:00:00                         622.0
# 6087       2020-07-13 19:00:00                         884.0
#
#       champs-elysees_Taux d'occupation  champs-elysees_Etat trafic  \
# 1793                          21.18723                           2
# 1457                          40.32833                           3
# 5964                          19.26056                           2
# ...

# %%
len(df_concat)
# Out:
# 9668

# %%
df_concat.columns
# Out:
# Index(['Date et heure de comptage', 'champs-elysees_Débit horaire',
#        'champs-elysees_Taux d'occupation', 'champs-elysees_Etat trafic',
#        'champs-elysees_Etat arc', 'filename', 'Date', 'Jour de la semaine_0',
#        'Jour de la semaine_1', 'Jour de la semaine_2', 'Jour de la semaine_3',
#        'Jour de la semaine_4', 'Jour de la semaine_5', 'Jour de la semaine_6',
#        'Etat du confinement', 'Couvre-feu', 'Jour férié', 'Vacances scolaires',
#        'Date des prochaines vacances scolaires',
#        'Temps avant les prochaines vacances scolaires', 'tempC',
#        'windspeedKmph', 'winddirDegree', 'weatherCode', 'precipMM', 'humidity',
#        'visibility', 'pressure', 'cloudcover', 'HeatIndexC', 'DewPointC',
#        'WindChillC', 'WindGustKmph', 'FeelsLikeC', 'hourly_uvIndex',
#        'maxtempC', 'mintempC', 'avgtempC', 'totalSnow_cm', 'sunHour',
#        'daily_uvIndex', 'sunrise', 'sunset', 'moon_phase', 'moon_illumination',
# ...

# %% [markdown]
# For convenience, we'll know reorder the columns.

# %%
columns_new_order = [
    'Date et heure de comptage', 'champs-elysees_Débit horaire',
    "champs-elysees_Taux d'occupation", 'champs-elysees_Etat trafic',
    'champs-elysees_Etat arc', 'convention_Débit horaire',
    "convention_Taux d'occupation", 'convention_Etat trafic',
    'convention_Etat arc', 'sts_Débit horaire', "sts_Taux d'occupation",
    'sts_Etat trafic', 'sts_Etat arc', 'filename', 'Date',
    'Jour de la semaine_0', 'Jour de la semaine_1', 'Jour de la semaine_2',
    'Jour de la semaine_3', 'Jour de la semaine_4', 'Jour de la semaine_5',
    'Jour de la semaine_6', 'Etat du confinement', 'Couvre-feu', 'Jour férié',
    'Vacances scolaires', 'Date des prochaines vacances scolaires',
    'Temps avant les prochaines vacances scolaires', 'tempC', 'windspeedKmph',
    'winddirDegree', 'weatherCode', 'precipMM', 'humidity', 'visibility',
    'pressure', 'cloudcover', 'HeatIndexC', 'DewPointC', 'WindChillC',
    'WindGustKmph', 'FeelsLikeC', 'hourly_uvIndex', 'maxtempC', 'mintempC',
    'avgtempC', 'totalSnow_cm', 'sunHour', 'daily_uvIndex', 'sunrise',
    'sunset', 'moon_phase', 'moon_illumination', 'Journée'
]

df_concat = df_concat[columns_new_order]
df_concat.head()
# Out:
#   Date et heure de comptage  champs-elysees_Débit horaire  \
# 0       2019-11-01 04:00:00                         746.0
# 1       2019-11-01 05:00:00                         549.0
# 2       2019-11-01 06:00:00                         503.0
# 3       2019-11-01 07:00:00                         500.0
# 4       2019-11-01 08:00:00                         525.0
#
#    champs-elysees_Taux d'occupation  champs-elysees_Etat trafic  \
# 0                          10.98889                           1
# 1                           7.40722                           1
# 2                           7.66667                           1
# 3                           4.75500                           1
# 4                           5.37389                           1
#
#   champs-elysees_Etat arc  convention_Débit horaire  \
# 0                Invalide                     323.0
# 1                Invalide                     272.0
# 2                Invalide                     240.0
# ...

# %%
df_concat.columns
# Out:
# Index(['Date et heure de comptage', 'champs-elysees_Débit horaire',
#        'champs-elysees_Taux d'occupation', 'champs-elysees_Etat trafic',
#        'champs-elysees_Etat arc', 'convention_Débit horaire',
#        'convention_Taux d'occupation', 'convention_Etat trafic',
#        'convention_Etat arc', 'sts_Débit horaire', 'sts_Taux d'occupation',
#        'sts_Etat trafic', 'sts_Etat arc', 'filename', 'Date',
#        'Jour de la semaine_0', 'Jour de la semaine_1', 'Jour de la semaine_2',
#        'Jour de la semaine_3', 'Jour de la semaine_4', 'Jour de la semaine_5',
#        'Jour de la semaine_6', 'Etat du confinement', 'Couvre-feu',
#        'Jour férié', 'Vacances scolaires',
#        'Date des prochaines vacances scolaires',
#        'Temps avant les prochaines vacances scolaires', 'tempC',
#        'windspeedKmph', 'winddirDegree', 'weatherCode', 'precipMM', 'humidity',
#        'visibility', 'pressure', 'cloudcover', 'HeatIndexC', 'DewPointC',
# ...

# %% [markdown]
# ## Export

# %% [markdown]
# On vérifie qu'on a bien la longueur attendue pour `df_concat`.

# %%
len(df_concat) == min([len(df_street) for df_street in l_df])
# Out:
# True

# %%
sep_date = pd.Timestamp('2020/11/23')
sep_date
# Out:
# Timestamp('2020-11-23 00:00:00')

# %%
df_concat_train = df_concat[df_concat['Date et heure de comptage'] < sep_date]
df_concat_test = df_concat[df_concat['Date et heure de comptage'] >= sep_date]

# %%
print(f'% train: {len(df_concat_train) / len(df_concat)}')
print(f'% test: {len(df_concat_test) / len(df_concat)}')
# Out:
# % train: 0.9576954902772031
# % test: 0.042304509722796854

# %% [markdown]
# À ce stade, le dataset concaténé a été entièrement nettoyé et est maintenant prêt à être utilisé ! ✅
# Dans la fonction de pipeline finale, on l'exportera sous forme de `pickle` pour conserver les différents formats dont `datetime`.

# %% [markdown]
# # Pipeline de synthèse

# %% [markdown]
# On supposera les fichiers `.csv` préalablement téléchargées et placés dans le répertoire `data` à la racine du repository du projet comme montré ci-dessous.
#
# <img src="ressources/file_organization.png" />
#
#
# Si ce n'est pas le cas ou si vous voulez télécharger les dernières versions de ces fichiers, voici à nouveau les liens pour récupérer les données utiles :
# - **Comptages routiers :**
#   - https://opendata.paris.fr/explore/dataset/comptages-routiers-permanents/information/?disjunctive.libelle&disjunctive.etat_trafic&disjunctive.libelle_nd_amont&disjunctive.libelle_nd_aval&sort=t_1h
#
# - **Jours fériés :**
#   - https://www.data.gouv.fr/en/datasets/jours-feries-en-france/
# - **Vacances scolaires :**
#   - https://www.data.gouv.fr/en/datasets/le-calendrier-scolaire/
# - **Données météo :**
#   - https://www.worldweatheronline.com/developer/api/docs/historical-weather-api.aspx.

# %% [markdown]
# Une fois les fichiers récupérés, on se prépare alors à lancer le module créé par nos soins.
# Voici la docstring de la fonction qui nous sera utile :

# %%
help(export_datasets)
# Out:
# Help on function export_datasets in module cleaning:
#
# export_datasets(sep_date_str, export=True)
#     Exports train and test sets in ./data folder as a pickle file. The data is in
#     chronological order and split using the given separation date.
#     Use pd.read_pickle to retrieve the data.
#
#     Args:
#         sep_date_str (string): String with default format for pd.Timestamp function
#         export (bool): Set to False if you don't want to write data in files.

# %% [markdown]
# On voit qu'il faut définir une date pour séparer le dataset en un trainset et un testset. Voici ci-dessous un widget pour sélectionner une date personalisée.
#
# **Remarque :** Le calendrier est mis à la valeur qui nous a servi lors de nos expériences et tests.

# %%
# Date de séparation pour le dataset utilisée lors de nos tests :
default_sep_date = datetime.strptime('2020-11-10', '%Y-%m-%d')

# On crée le DatePicker :
widget_sep_date = widgets.DatePicker(
        description='sep_date',
        disabled=False,
        value=default_sep_date
    )

# On récupère la 1ère valeur du DatePicker à l'initialisation :
sep_date = widget_sep_date.value

# Fonction auxiliaire qui sera appelée dès que la valeur du
# DatePicker aura changé :
def on_change(v):
    global sep_date
    sep_date = v['new']
    return

# Instanciation de l'observateur :
widget_sep_date.observe(on_change, names='value')

# Affichage du widget :
display(widget_sep_date)
# Out:
# DatePicker(value=datetime.datetime(2020, 11, 10, 0, 0), description='Separation date')

# %% [markdown]
# **NB :** Si vous utilisez *Safari*, il est normal que vous ne puissiez pas voire le sélecteur de date. Utilisez plutôt *Chrome*, *Firefox* ou *Edge*.

# %%
df_train, df_test = export_datasets(sep_date_str=sep_date_str)

print(f'len(df_train): {len(df_train)}\nlen(df_test): {len(df_test)}')

# %% [markdown]
# # Génération du trainset qui servira à la prédiction finale

# %% [markdown]
# ‼️ Attention, la plupart des fichiers précédemment générés seront écrasés. Vous pouvez néanmoins les retrouver dans `data/data_for_baseline`comme indiqué en introduction. ‼️

# %%
sep_date_str = '2020/12/12' # date à partir de laquelle il faut prédire pour le challenge
export_datasets(sep_date_str=sep_date_str);

# %% [markdown]
# # Prédiction avec SARIMA

# %% [markdown]
# ## Présentation du modèle retenu

# %% [markdown]
# ## Chargement et nettoyage des données

# %%
df = pd.read_pickle("data/df_train.pkl")
df_ACE = df[df['filename']=='champs-elysees.csv']
df_Sts = df[df['filename']=='convention.csv']
df_convention = df[df['filename']=='sts.csv']

df_test = pd.read_pickle("data/df_test.pkl")
df_ACE_test = df_test[df_test['filename']=='champs-elysees.csv']
df_Sts_test = df_test[df_test['filename']=='convention.csv']
df_convention_test = df_test[df_test['filename']=='sts.csv']


dfs = [df_ACE, df_Sts, df_convention]
dfs_test = [df_ACE_test, df_Sts_test, df_convention_test]

# %% [markdown]
# ## Traitement des dates

# %%
# Format d'une série temporelle
for df in dfs:
    df['Date et heure de comptage']= pd.to_datetime(df["Date et heure de comptage"], format='%Y-%m-%d %H:%M:%S')
    
# for df in dfs_test:
#     df['Date et heure de comptage']= pd.to_datetime(df["Date et heure de comptage"], format='%Y-%m-%d %H:%M:%S')
    
# Lignes rangées par ordre chronologique
for df in dfs:
    df.sort_values("Date et heure de comptage",inplace = True)
    
for df in dfs_test:
    df.sort_values("Date et heure de comptage",inplace = True)

def index_and_freq(df):
    df = df.set_index('Date et heure de comptage')
    df = df.asfreq('H', method= 'ffill')
    return df

tagg = ['Champs-Élysées', 'Convention', 'Sts-Pères']
    
# Nous indiquons que la série temporelle est indexée selon la date
df_ACE = index_and_freq(df_ACE)
df_convention = index_and_freq(df_convention)
df_Sts = index_and_freq(df_Sts)

df_ACE_test = index_and_freq(df_ACE_test)
df_Sts_test = index_and_freq(df_Sts_test)
df_convention_test = index_and_freq(df_convention_test)
# Out:
# C:\Users\carlo\Anaconda3\envs\datathon\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %% [markdown]
# ## Quelques fonctions utilitaires

# %%
def create_df(original_df):
    data = pd.DataFrame()
    data['debit'] = original_df['Débit horaire']
    data['taux'] = original_df["Taux d'occupation"]
    data['date'] = original_df.index
    data.sort_values("date",inplace = True)
    data = data.set_index('date')
    data = data.asfreq('H', method= 'ffill')
    return data

def string_to_model(model):
    p = int(model[1])
    q = int(model[4])
    d = int(model[7])
    seasonal = (int(model[10]), int(model[13]), int(model[16]), int(model[19:21]))
    return p,q,d,seasonal

# %%
def plotting_predictions(X_train, pred, title):
    plt.plot(X_train, label='Données')
    plt.plot(pred, label='Prediction')
    plt.xticks(rotation=45)
    plt.title(title)
    plt.legend()
    plt.show()

# %% [markdown]
# ## Modèles retenus

# %% [markdown]
# Nous avons lancé un GridSearch pour trouver les hyperparamètres optimaux pour le modèle SARIMA. Le calcul ayant pris plus de 24h sur nos machines, nous avons tout simplement noté les résultats du GridSearch dans deux dictionnaires.
#
# Nous désignerons par les entiers suivants les rues dans les 2 dictionnaires suivants :
# - 0 -> Champs-Elysees
# - 1 -> Sts-Peres
# - 2 -> Convention.

# %%
modeles_debit = {0: '(4, 1, 5)(4, 1, 4, 24)', 2: '(4, 1, 5)(4, 1, 4, 24)', 1:'(4, 1, 5)(4, 1, 4, 24)'}
modeles_taux = {0: '(1, 0, 1)(2, 1, 1, 24)', 2: '(1, 0, 1)(2, 1, 1, 24)', 1:'(2, 0, 2)(1, 1, 1, 24)'}

# %% [markdown]
# ## Géneration des prédictions

# %% [markdown]
# La cellule suivante prend un peu de temps à terminer, mais elle affiche chaque nouveau plot obtenu dès que le calcul correspondant termine. Ceci permet d'avoir rapidement une idée de la qualité de notre modèle.

# %%
df_predictions = pd.DataFrame()

for model_index,df in tqdm(enumerate([df_ACE, df_Sts, df_convention])):
    
    # Paramètres des modèles
    p_debit,d_debit,q_debit,seasonal_debit = string_to_model(modeles_debit[model_index])
    p_taux,d_taux,q_taux,seasonal_taux = string_to_model(modeles_taux[model_index])
    
    # Dates de prédiction
    start = datetime.strptime('2020-12-11 01:00:00', '%Y-%m-%d %H:%M:%S')
    end = datetime.strptime('2020-12-16 23:00:00', '%Y-%m-%d %H:%M:%S')
    
    # Dates de corréction
    start_dec = datetime.strptime('2020-12-09 00:00:00', '%Y-%m-%d %H:%M:%S')
    end_dec = datetime.strptime('2020-12-10 00:00:00', '%Y-%m-%d %H:%M:%S')
    
    # Création des timeseries pour débit horaire et taux d'occupation
    debit_train_raw = create_df(df).loc['2020-08-01':'2020-12-11 00:00:00'].debit
    taux_train_raw = create_df(df).loc['2020-08-01':'2020-12-11 00:00:00'].taux
        
    # Correction des données du 9 décembre
    mod_debit_corr = sm.tsa.statespace.SARIMAX(debit_train_raw.loc['2020-11-01':'2020-12-09 00:00:00'],order=(p_debit,d_debit,q_debit),seasonal_order=seasonal_debit,enforce_stationarity=False,enforce_invertibility=False)
    model_debit_corr = mod_debit_corr.fit()
    debit_correc = model_debit_corr.predict(start=start_dec,end=end_dec)
    
    mod_taux_corr = sm.tsa.statespace.SARIMAX(taux_train_raw.loc['2020-11-01':'2020-12-09 00:00:00'],order=(p_taux,d_taux,q_taux),seasonal_order=seasonal_taux,enforce_stationarity=False,enforce_invertibility=False)
    model_taux_corr = mod_taux_corr.fit()
    taux_correc = model_taux_corr.predict(start=start_dec,end=end_dec)
    
    # Correction des données:
    debit_train_raw[start_dec : end_dec] = debit_correc
    taux_train_raw[start_dec : end_dec] = taux_correc 
        
    # Ajustement du modèle pour le débit horaire
    mod_debit = sm.tsa.statespace.SARIMAX(debit_train_raw,order=(p_debit,d_debit,q_debit),seasonal_order=seasonal_debit,enforce_stationarity=False,enforce_invertibility=False)
    model_debit = mod_debit.fit()
    debit_pred = model_debit.predict(start=start,end=end)
    
    # Ajustement du modèle pour le taux d'occupation
    mod_taux = sm.tsa.statespace.SARIMAX(taux_train_raw,order=(p_taux,d_taux,q_taux),seasonal_order=seasonal_taux,enforce_stationarity=False,enforce_invertibility=False)
    model_taux = mod_taux.fit()
    taux_pred = model_taux.predict(start=start,end=end)
    
    # Rajout des données au DataFrame
    temp_df = pd.DataFrame()
    temp_df['Datetime'] = taux_pred.index
    temp_df['Arc'] = [tagg[model_index] for i in range(len(taux_pred))]
    temp_df["Débit horaire"] = debit_pred.values
    temp_df["Taux d'occupation"] = taux_pred.values
    
    # Rajout des données de minuit (une ligne)
    first_hour = pd.DataFrame()
    first_hour['Datetime'] = [taux_train.index[-1]]
    first_hour['Arc'] = [tagg[model_index]]
    first_hour["Taux d'occupation"] = [taux_train.values[-1]]
    first_hour["Débit horaire"] = [debit_train.values[-1]]
    
    temp_df = temp_df.append(first_hour)
    temp_df.sort_values("Datetime",inplace = True)
    df_predictions = pd.concat([df_predictions, temp_df])
        
    rcParams['figure.figsize'] = 12, 4
    plotting_predictions(debit_train_raw.loc['2020-11-01':'2020-12-11 00:00:00'], debit_pred, "Débit horaire " + tagg[model_index])
    plotting_predictions(taux_train_raw.loc['2020-11-01':'2020-12-11 00:00:00'], taux_pred, "Taux d'occupation " + tagg[model_index])
# Out:
# 0it [00:00, ?it/s]
# 1it [30:00, 1800.61s/it]
# 2it [1:01:31, 1827.62s/it]
# 3it [1:31:14, 1824.82s/it]

# %% [markdown]
# ## Export des prédictions

# %% [markdown]
# Les données ayant déjà mises en forme conformément à ce qui a été demandé dans les consignes du challenge, il ne nous reste plus qu'à les exporter dans un fichier `output.csv`.

# %%
df_predictions.to_csv('output.csv', index=False)

# %%
df_predictions.head()
# Out:
#              Datetime             Arc  Débit horaire  Taux d'occupation
# 0 2020-12-11 00:00:00  Champs-Élysées     247.000000           2.981110
# 0 2020-12-11 01:00:00  Champs-Élysées     175.105746           2.349191
# 1 2020-12-11 02:00:00  Champs-Élysées     129.010708           1.785235
# 2 2020-12-11 03:00:00  Champs-Élysées      68.825435           1.345536
# 3 2020-12-11 04:00:00  Champs-Élysées      22.530303           1.054927

# %% [markdown]
# # Conclusion
